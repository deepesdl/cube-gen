# %%
from xcube.core.store import find_data_store_extensions
from xcube.core.store import get_data_store_params_schema
from xcube.core.store import new_data_store

import matplotlib.pyplot as plt

from tqdm import tqdm
import xarray as xr
import numpy as np
import os

# %%
store = new_data_store("s3", root="deep-esdl-output")

# %%
list(store.get_data_ids())
# Out:
# ['C3S_CCI_LC.zarr',
#  'LC-1x2160x2160_v1.levels',
#  'LC-1x2160x2160_v1.zarr',
#  'SMOS-snow-1x720x720_v1.zarr',
#  'SMOS-snow-1x720x720_v2.zarr',
#  'SMOS-snow-1x720x720_v3.zarr',
#  'SMOS-snow-485x60x60_v2.zarr',
#  'black-sea-1x1024x1024.levels',
#  'black-sea-1x1024x1024.zarr',
#  'black-sea-256x128x128.zarr',
#  'esdc-8d-0.25deg-1x720x1440-3.0.0.zarr',
#  'esdc-8d-0.25deg-1x720x1440-3.0.1.zarr',
#  'esdc-8d-0.25deg-1x720x1440-3.0.2.zarr',
#  'esdc-8d-0.25deg-1x720x512-3.0.0.zarr',
#  'esdc-8d-0.25deg-256x128x128-3.0.0.zarr',
#  'esdc-8d-0.25deg-256x128x128-3.0.1.zarr',
#  'esdc-8d-0.25deg-256x128x128-3.0.2.zarr',
#  'ocean-1M-4km-64x256x256-1.0.0.zarr',
#  'ocean-1M-9km-64x256x256-1.0.0.zarr',
#  'polar-100m-1x2048x2048-v1.0.0.zarr']

# %%
da = store.open_data('ocean-1M-4km-64x256x256-1.0.0.zarr')
da
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 271, lat: 4320, lon: 8640)
# Coordinates:
#   * lat       (lat) float32 89.98 89.94 89.9 89.85 ... -89.9 -89.94 -89.98
#   * lon       (lon) float32 -180.0 -179.9 -179.9 -179.9 ... 179.9 179.9 180.0
#   * time      (time) datetime64[ns] 1997-09-01 1997-10-01 ... 2020-03-01
# Data variables:
#     POC       (time, lat, lon) float32 dask.array<chunksize=(64, 256, 256), meta=np.ndarray>
#     POC_bias  (time, lat, lon) float32 dask.array<chunksize=(64, 256, 256), meta=np.ndarray>
#     POC_rmsd  (time, lat, lon) float32 dask.array<chunksize=(64, 256, 256), meta=np.ndarray>
#     Rrs_443   (time, lat, lon) float32 dask.array<chunksize=(64, 256, 256), meta=np.ndarray>
#     Rrs_555   (time, lat, lon) float32 dask.array<chunksize=(64, 256, 256), meta=np.ndarray>
# Attributes: (12/21)
#     Conventions:                CF-1.10
#     acknowledgment:             All data providers are acknowledged inside ea...
# ...

# %%
da.POC[0].plot.imshow(robust=True)

# %%
da.POC_bias[0].plot.imshow(robust=True)

# %%
da.POC_rmsd[0].plot.imshow(robust=True)

# %%
da.Rrs_443[0].plot.imshow(robust=True)

# %%
da.Rrs_555[0].plot.imshow(robust=True)
